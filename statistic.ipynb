# %%
import pandas as pd

# %%
# Load Dataset
df = pd.read_csv("C:\\Users\\prati\\Downloads\\Salary_Data.csv")

# View columns
print(df.head())
# Out:
#    YearsExperience   Salary
# 0              1.1  39343.0
# 1              1.3  46205.0
# 2              1.5  37731.0
# 3              2.0  43525.0
# 4              2.2  39891.0

# %%
# Create a new Categorical Column based on 'YearsExperience'
def categorize_experience(exp):
    if exp <= 3:
        return 'Fresher'
    elif exp <= 7:
        return 'Junior'
    else:
        return 'Senior'

df['Experience_Group'] = df['YearsExperience'].apply(categorize_experience)

# %%
# Display to verify
print(df[['YearsExperience', 'Experience_Group']].head())
# Out:
#    YearsExperience Experience_Group
# 0              1.1          Fresher
# 1              1.3          Fresher
# 2              1.5          Fresher
# 3              2.0          Fresher
# 4              2.2          Fresher

# %%
# Group by the new categorical variable and calculate summary statistics
grouped_stats = df.groupby('Experience_Group')['Salary']

# %%
# Mean Salary by Experience Group
print("Mean Salary:")
print(grouped_stats.mean())
# Out:
# Mean Salary:
# Experience_Group
# Fresher     46212.428571
# Junior      68166.857143
# Senior     111363.000000
# Name: Salary, dtype: float64

# %%
# Median Salary
print("\nMedian Salary:")
print(grouped_stats.median())
# Out:
# Median Salary:
# Experience_Group
# Fresher     43525.0
# Junior      63831.5
# Senior     112635.0
# Name: Salary, dtype: float64

# %%
# Minimum Salary
print("\nMinimum Salary:")
print(grouped_stats.min())
# Out:
# Minimum Salary:
# Experience_Group
# Fresher    37731.0
# Junior     54445.0
# Senior     98273.0
# Name: Salary, dtype: float64

# %%
# Maximum Salary
print("\nMaximum Salary:")
print(grouped_stats.max())
# Out:
# Maximum Salary:
# Experience_Group
# Fresher     60150.0
# Junior      93940.0
# Senior     122391.0
# Name: Salary, dtype: float64

# %%
# Standard Deviation
print("\nStandard Deviation of Salary:")
print(grouped_stats.std())
# Out:
# Standard Deviation of Salary:
# Experience_Group
# Fresher     8844.379795
# Junior     13643.344745
# Senior      8520.732744
# Name: Salary, dtype: float64

# %%
# All Summary Stats Together
print("\nSummary Statistics:")
print(grouped_stats.agg(['mean', 'median', 'min', 'max', 'std']))
# Out:
# Summary Statistics:
#                            mean    median      min       max           std
# Experience_Group
# Fresher            46212.428571   43525.0  37731.0   60150.0   8844.379795
# Junior             68166.857143   63831.5  54445.0   93940.0  13643.344745
# Senior            111363.000000  112635.0  98273.0  122391.0   8520.732744

# %%
# Create a list: Numeric value (average salary) for each Experience Group
experience_salary_list = grouped_stats.mean().tolist()
print("\nList of Average Salaries by Experience Group:", experience_salary_list)
# Out:
# List of Average Salaries by Experience Group: [46212.42857142857, 68166.85714285714, 111363.0]

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
# Load the Iris Dataset
df1 = pd.DataFrame(iris.data, columns=iris.feature_names)

# %%
df1['variety'] = pd.Categorical.from_codes(iris.target, iris.target_names)

# %%
grouped_stats1 = df1.groupby('variety')['sepal length (cm)']
print(grouped_stats1.agg(['mean', 'median', 'min', 'max', 'std']))
# Out:
#              mean  median  min  max       std
# variety
# setosa      5.006     5.0  4.3  5.8  0.352490
# versicolor  5.936     5.9  4.9  7.0  0.516171
# virginica   6.588     6.5  4.9  7.9  0.635880
# C:\Users\prati\AppData\Local\Temp\ipykernel_4312\3957709591.py:1: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_stats1 = df1.groupby('variety')['sepal length (cm)']

# %%
# Check for missing values
df1.isnull().sum()
# Out:
# sepal length (cm)    0
# sepal width (cm)     0
# petal length (cm)    0
# petal width (cm)     0
# variety              0
# dtype: int64

# %%
# View first 5 records
df1.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)  \
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2
#
#   variety
# 0  setosa
# 1  setosa
# 2  setosa
# 3  setosa
# 4  setosa

# %%
# Aggregate Mean, Median, Min, Max, and Std
print(grouped_stats1.agg(['mean', 'median', 'min', 'max', 'std']))
# Out:
#              mean  median  min  max       std
# variety
# setosa      5.006     5.0  4.3  5.8  0.352490
# versicolor  5.936     5.9  4.9  7.0  0.516171
# virginica   6.588     6.5  4.9  7.9  0.635880

# %%
# Filter data based on Species
Setosa = df1[df1['variety'] == 'Iris-Setosa']
Versicolor = df1[df1['variety'] == 'Iris-Versicolor']
Virginica = df1[df1['variety'] == 'Iris-Virginica']

# %%
# Display first few rows (optional)
print(Setosa.head())
# Out:
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), variety]
# Index: []

# %%
print(Versicolor.head())
# Out:
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), variety]
# Index: []

# %%
print(Virginica.head())
# Out:
# Empty DataFrame
# Columns: [sepal length (cm), sepal width (cm), petal length (cm), petal width (cm), variety]
# Index: []
